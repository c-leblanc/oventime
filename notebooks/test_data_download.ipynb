# %%
import oven_time.api as api

api.download_raw_data_24H()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[1], line 3
#       1 import oven_time.api as api
# ----> 3 api.download_raw_data_24H()
#
# AttributeError: module 'oven_time.api' has no attribute 'download_raw_data_24H'
